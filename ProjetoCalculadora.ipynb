# %%
print ('--------Projeto Calculadora--------')



números = input('Quais são os números?')
# Out:
# --------Projeto Calculadora--------
# Quais são os números?8 e 4

# %% [markdown]
# Operações Aritméticas

# %%
# Adição

8+4
# Out:
# 12

# %%
# Subtração

8-4
# Out:
# 4

# %%
#Multiplicação

8*4
# Out:
# 32

# %%
#Divisão Real

8/4
# Out:
# 2.0

# %%
#Divisão Inteira

8//4
# Out:
# 2

# %%
# Potenciação

8**4
# Out:
# 4096

# %% [markdown]
# Concatenando

# %%
x = 4

print('O valor de x é', x)
# Out:
# O valor de x é 4

# %%
x = 4
y = 8

print('O valor de x é', x, 'e o valor de y é', y)
# Out:
# O valor de x é 4 e o valor de y é 8

# %%
print('O dobro de x é', x * 2, 'O triplo de y é', y * 2)
# Out:
# O dobro de x é 8 O triplo de y é 16

# %% [markdown]
# Estrutura condicional

# %%
número = 8

if número == 8:
  print('O número é igual a 8')
# Out:
# O número é igual a 8

# %%
if 4 > 8:
  print('O número é maior que 10')

else:
  print('O número é menor que 10')
# Out:
# O número é menor que 10

# %% [markdown]
# Simulando notas de alunos, Somátorio de notas!
#
# Transformando valores de string para int

# %%
nota1 = int(input("Qual valor da nota1?"))
nota2 = int(input("Qual valor da nota2?"))
# Out:
# Qual valor da nota1?8
# Qual valor da nota2?4

# %%
# Somatório das notas

total = nota1 + nota2




print("O aluno", "teve nota total de", total )
# Out:
# O aluno teve nota total de 12

# %% [markdown]
# Estrutrura condicional das notas acima

# %%
# Aluno tirou 8

if nota1== 8 or nota2 == 4:
  print('Aluno tirou 8, por isso, Aprovado')

else:
  print('Aluno tirou 4, por isso, Reprovado')
# Out:
# Aluno tirou 8, por isso, Aprovado
